# %%
from matplotlib import pyplot as plt
import matplotlib
import numpy as np

# %%
def cost(x):
    tar = 4
    return (x-tar) ** 2

# %%
def num_slope(b): 
    h = 0.0001
    return (cost(b+h) - cost(b))/h

# %%
cost(3.98)
# Out:
# 0.0004000000000000007

# %%
num_slope(3.98)
# Out:
# -0.039900000000083966

# %%
def slope_calc(b):
    return 2 * (b-4)

# %%
slope_calc(3.98)
# Out:
# -0.040000000000000036

# %%
b = 8

# %%
#training loop
for i in range(10):
    b = b - 0.1 * slope_calc(b)
    print(b)
# Out:
# 4.000000000651852
# 4.0000000005214815
# 4.000000000417185
# 4.000000000333748
# 4.000000000266999
# 4.000000000213599
# 4.000000000170879
# 4.000000000136703
# 4.000000000109362
# 4.00000000008749

# %%
fig = plt.figure()  
fig.suptitle('No axes on this figure')  
fig, ax_lst = plt.subplots(2, 2)

# %%
x = np.arange(0, 10, 0.2)
print(x)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8 5.  5.2 5.4 5.6 5.8 6.  6.2 6.4 6.6 6.8 7.
#  7.2 7.4 7.6 7.8 8.  8.2 8.4 8.6 8.8 9.  9.2 9.4 9.6 9.8]

# %%
def wags_pats(x):
    arr = np.array([0.,0.,0.])
    for i in range(3):
        print(x)
        arr[i] = w*x[i] + b
        print(arr[i])
    return arr

# %%
def overall_cost(w, b, target):
    target_index = 0
    cost = 1
    for i in pats:
        cost = cost + (wags_pats(i) - target[target_index])**2
        target_index = target_index + 1

# %%
w = 0.25
b = 0.68
pats = np.array([1,2,4])
wp_arr = wags_pats(pats)

plt.plot(pats, wp_arr)
plt.plot()
# Out:
# [1 2 4]
# 0.93
# [1 2 4]
# 1.1800000000000002
# [1 2 4]
# 1.6800000000000002

# %%
# Cost for one point (ci) = (x-y)^2 (Actual - predicted)
# WE cannot change inputs from the data to approxmiate but we can change w and b. 
# Overall COST = c1 * c2 * c3. Each c represents a point error (sqaured difference between x and y)
# If I reduce overall cost, I Will have a suitable cost. 
# Average squared error = (1/m) * Overall cost .... Where m is the no. of data points

# %%
# Above, I derived the sum of sqaured errors cost function for the linear regression
# NEXT, I take the partial derivate of the cost function with respect to parameters w & b. 
# This will advise on how to change w & b to find the line that goes through data points
# Partial derviative is taken because we no longer have one parameter to take but two parameters (w & b)
# Watch video 10 of creating NN to get intuiton on finding minimum of cost surface and computing Gradients
